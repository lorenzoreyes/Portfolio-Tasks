# %% [markdown]
# # Use fisher library for tech analysis
# # & backtest indicators deployment

# %%
import pandas as pd
import numpy as np 
import yfinance as yahoo

import fisher

# %% [markdown]
# # Use Coca-Cola Stock for the examples
# # Fisher Simple-Moving-Average

# %%
cokeSMA = fisher.Strategy.SimpleMovingAverage(symbol='KO', num_days=100)
cokeSMA
# signal is a conditional if SMA-period > StockPrice buy, else sell
# positions tracks signal differences
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    KO     SMA100  signal  positions
# Date
# 2020-01-13  54.272751  54.272751     0.0        NaN
# 2020-01-14  54.147049  54.209900     1.0        1.0
# 2020-01-15  54.823887  54.414562     0.0       -1.0
# 2020-01-16  54.939919  54.545901     0.0        0.0
# 2020-01-17  55.055946  54.647910     0.0        0.0
# ...               ...        ...     ...        ...
# 2021-01-06  50.520000  50.550171     1.0        1.0
# 2021-01-07  49.959999  50.572900     1.0        0.0
# 2021-01-08  51.080002  50.609192     0.0       -1.0
# 2021-01-11  50.200001  50.634617     1.0        1.0
# 2021-01-12  50.119999  50.669576     1.0        0.0
#
# [253 rows x 4 columns]

# %%
cokeSMA.iloc[:,:2].plot(figsize=(12,6),grid=True, lw=3.0)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Fisher-Momentum

# %%
cokeMOM = fisher.Strategy.Momentum(symbol='KO',num_days=50)
cokeMOM
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    KO  Momentum  signal  positions
# Date
# 2020-01-13  54.272751  1.000000     1.0        NaN
# 2020-01-14  54.147049  0.998841     1.0        0.0
# 2020-01-15  54.823887  1.007522     1.0        0.0
# 2020-01-16  54.939919  1.007224     1.0        0.0
# 2020-01-17  55.055946  1.007467     1.0        0.0
# ...               ...       ...     ...        ...
# 2021-01-06  50.520000  0.969744     1.0        0.0
# 2021-01-07  49.959999  0.958793     1.0        0.0
# 2021-01-08  51.080002  0.979698     1.0        0.0
# 2021-01-11  50.200001  0.961855     1.0        0.0
# 2021-01-12  50.119999  0.959413     1.0        0.0
#
# [253 rows x 4 columns]

# %%
cokeMOM['Momentum'].plot(figsize=(12,6),grid=True,legend=True, lw=3.0)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Fisher-Bollinger-Bands

# %%
cokeBB = fisher.Strategy.BollingerBands(symbol='KO',num_days=50,stdev_factor=2)
cokeBB
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    KO  MiddleBand  UpperBand  LowerBand
# Date
# 2020-01-13  54.272751   54.272751        NaN        NaN
# 2020-01-14  54.147049   54.209900  54.387669  54.032131
# 2020-01-15  54.823887   54.414562  55.134591  53.694534
# 2020-01-16  54.939919   54.545901  55.334334  53.757468
# 2020-01-17  55.055946   54.647910  55.469090  53.826730
# ...               ...         ...        ...        ...
# 2021-01-06  50.520000   52.096218  55.966591  48.225846
# 2021-01-07  49.959999   52.107167  55.949549  48.264785
# 2021-01-08  51.080002   52.138532  55.919555  48.357509
# 2021-01-11  50.200001   52.190794  55.782524  48.599064
# 2021-01-12  50.119999   52.240266  55.639495  48.841037
#
# [253 rows x 4 columns]

# %%
cokeBB.plot(figsize=(12,6),grid=True,lw=3.0)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Fisher-Standard-Deviation

# %%
cokeStDev = fisher.Strategy.StandardDeviation(symbol='KO',num_days=50)
cokeStDev
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    KO   StDev50
# Date
# 2020-01-13  54.272751       NaN
# 2020-01-14  54.147049  0.088885
# 2020-01-15  54.823887  0.360014
# 2020-01-16  54.939919  0.394216
# 2020-01-17  55.055946  0.410590
# ...               ...       ...
# 2021-01-06  50.520000  1.935186
# 2021-01-07  49.959999  1.921191
# 2021-01-08  51.080002  1.890511
# 2021-01-11  50.200001  1.795865
# 2021-01-12  50.119999  1.699615
#
# [253 rows x 2 columns]

# %%
cokeStDev['StDev50'].plot(figsize=(12,6),grid=True,legend=True,lw=3.0)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Fisher-Absolute-Price-Oscillator

# %%
cokeAPO = fisher.Strategy.AbsolutePriceOscillator(symbol='KO',short=20,long=100)
cokeAPO
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    KO  shortAPO20  longAPO100
# Date
# 2020-01-13  54.272751    0.000000    0.000000
# 2020-01-14  54.147049   -0.062851   -0.062851
# 2020-01-15  54.823887    0.409325    0.409325
# 2020-01-16  54.939919    0.394017    0.394017
# 2020-01-17  55.055946    0.408036    0.408036
# ...               ...         ...         ...
# 2021-01-06  50.520000   -2.740500   -0.030170
# 2021-01-07  49.959999   -3.139501   -0.612901
# 2021-01-08  51.080002   -1.906998    0.470810
# 2021-01-11  50.200001   -2.644499   -0.434616
# 2021-01-12  50.119999   -2.563001   -0.549578
#
# [253 rows x 3 columns]

# %%
cokeAPO.iloc[:,1:].plot(figsize=(12,6),grid=True,lw=3.0)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Fisher-Relative-Strength-Index-(RSI)

# %%
cokeRSI = fisher.Strategy.RelativeStrenghtIndex(symbol='KO',time_period=50)
cokeRSI
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    KO  difference      loss      gain     KO RSI
# Date
# 2020-01-13  54.272751    0.000000  0.000000  0.000000        NaN
# 2020-01-14  54.147049   -0.125702 -0.125702  0.000000   0.000000
# 2020-01-15  54.823887    0.676838  0.000000  0.676838  84.336989
# 2020-01-16  54.939919    0.116032  0.000000  0.116032  86.315501
# 2020-01-17  55.055946    0.116028  0.000000  0.116028  87.850185
# ...               ...         ...       ...       ...        ...
# 2021-01-06  50.520000   -1.660000 -1.660000  0.000000  50.691990
# 2021-01-07  49.959999   -0.560001 -0.560001  0.000000  50.969097
# 2021-01-08  51.080002    1.120003  0.000000  1.120003  52.679286
# 2021-01-11  50.200001   -0.880001 -0.880001  0.000000  54.629803
# 2021-01-12  50.119999   -0.080002 -0.080002  0.000000  54.379407
#
# [253 rows x 5 columns]

# %%
cokeRSI['KO RSI'].plot(figsize=(12,6),grid=True,lw=3.0,legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Fisher-Moving-Average-Convergence-Divergence-(MACD)

# %%
cokeMACD = fisher.Strategy.MovingAverageConvergenceDivergence(symbol='KO',short=20,long=100)
cokeMACD
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    KO   MACD KO
# Date
# 2020-01-13  54.272751  0.000000
# 2020-01-14  54.147049  0.000000
# 2020-01-15  54.823887  0.000000
# 2020-01-16  54.939919  0.000000
# 2020-01-17  55.055946  0.000000
# ...               ...       ...
# 2021-01-06  50.520000  2.710329
# 2021-01-07  49.959999  2.526600
# 2021-01-08  51.080002  2.377808
# 2021-01-11  50.200001  2.209883
# 2021-01-12  50.119999  2.013424
#
# [253 rows x 2 columns]

# %%
cokeMACD['MACD KO'].plot(figsize=(12,6),grid=True,legend=True,lw=3.0)
# Out:
# <AxesSubplot:xlabel='Date'>
